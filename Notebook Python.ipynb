# %% [markdown]
# ### Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import datetime

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, roc_curve
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SKRIPSI/Data Mentah.csv')

# %%
df
# Out:
#             NPM Jenis Kelamin    Tempat Lahir  ... SKS 5 SKS 6 Tanggal Yudisium
# 0    1434010001     Laki-laki   Kab. Sidoarjo  ...    23    19        7/31/2018
# 1    1434010002     Laki-laki  Kodya Surabaya  ...    23    16        6/30/2020
# 2    1434010003     Laki-laki  Kodya Surabaya  ...    23    19        5/28/2019
# 3    1434010004     Laki-laki   Kab. Sidoarjo  ...    23    19        1/22/2019
# 4    1434010005     Laki-laki  Kodya Surabaya  ...    23    16         6/6/2018
# ..          ...           ...             ...  ...   ...   ...              ...
# 400  1635010076     Laki-laki   Kota Surabaya  ...    20    23        1/30/2021
# 401  1635010077     Perempuan   Kota Surabaya  ...    20    23        9/30/2020
# 402  1635010078     Laki-laki   Kota Surabaya  ...    20    23        1/30/2021
# 403  1635010079     Laki-laki   Kota Surabaya  ...    23    23        1/30/2021
# 404  1635010080     Perempuan   Kota Surabaya  ...    23    20        1/30/2021
#
# [405 rows x 20 columns]

# %% [markdown]
# Jumlah baris: 405 baris
#
# Jumlah kolom: 20 kolom

# %% [markdown]
# Atribut:
# *   NPM digunakan untuk mencari angkatan (14, 15, 16)
# *   Tempat lahir untuk mencari asal (kolom baru) : surabaya, luar surabaya
# *   tanggal lahir lahir untuk mencari usia (kolom baru): tgl semester 6 - tgl lahir
# *   Baris organisasi yang nggak kosong, diisi dengan 'Tidak'
# *   Tanggal yudisium untuk mencari keputusan (kolom baru): tgl yudisum > tgl batas yudisium
#
# Atribut yang dihapus:
# NPM, tempat lahir, tanggal lahir, tanggal yudisium
#
# Atribut yang ada:
# Jurusan, jenis kelamin, usia, asal, jalur masuk, golongan ukt, organisasi, IPS 1-5, SKS 1-6, Keputusan

# %% [markdown]
# ### Data Preparation

# %%
df.dtypes
# Out:
# NPM                   int64
# Jenis Kelamin        object
# Tempat Lahir         object
# Tanggal Lahir        object
# Jalur Masuk          object
# Jurusan              object
# Golongan UKT          int64
# Organisasi           object
# IPS 1               float64
# IPS 2               float64
# IPS 3               float64
# IPS 4               float64
# IPS 5               float64
# SKS 1                 int64
# SKS 2                 int64
# SKS 3                 int64
# SKS 4                 int64
# SKS 5                 int64
# SKS 6                 int64
# Tanggal Yudisium     object
# dtype: object

# %%
df.shape
# Out:
# (405, 20)

# %%
df.describe()
# Out:
#                 NPM  Golongan UKT  ...       SKS 5       SKS 6
# count  4.050000e+02    405.000000  ...  405.000000  405.000000
# mean   1.513874e+09      3.560494  ...   22.360494   21.219753
# std    7.750325e+07      2.046349  ...    1.526473    2.762659
# min    1.434010e+09      1.000000  ...   13.000000   10.000000
# 25%    1.434010e+09      2.000000  ...   22.000000   19.000000
# 50%    1.534010e+09      3.000000  ...   23.000000   22.000000
# 75%    1.535010e+09      5.000000  ...   23.000000   23.000000
# max    1.635010e+09      8.000000  ...   25.000000   24.000000
#
# [8 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# NPM                   0
# Jenis Kelamin         0
# Tempat Lahir          0
# Tanggal Lahir         0
# Jalur Masuk           0
# Jurusan               0
# Golongan UKT          0
# Organisasi          298
# IPS 1                 0
# IPS 2                 0
# IPS 3                 0
# IPS 4                 0
# IPS 5                 0
# SKS 1                 0
# SKS 2                 0
# SKS 3                 0
# SKS 4                 0
# SKS 5                 0
# SKS 6                 0
# Tanggal Yudisium      0
# dtype: int64

# %% [markdown]
# Missing value : Organisasi

# %% [markdown]
# ##### Usia, Asal, Keputusan

# %%
# agar mempermudah memotong per hurufnya dari kata
df.NPM = df.NPM.astype(str)

# %%
# fungsi untuk perhitungan tanggal
def calculateDate(st_date, nd_date):
    st_date = datetime.datetime.strptime(st_date, '%m/%d/%Y')
    nd_date = datetime.datetime.strptime(nd_date, '%m/%d/%Y')
    
    # untuk menghitung usia dalam tahun
    age = nd_date.year - st_date.year - ((nd_date.month, nd_date.day) < (st_date.month, st_date.day))
    
    # untuk mengetahui keputusan
    if st_date > nd_date:
      decision = 'Terlambat'
    else:
      decision = "Tepat"

    # mengembalikan hasil perhitungan
    return age, decision

# %%
# data disimpan dalam array untuk menjadi kolom baru
usia=[]
asal=[]
keputusan=[]
ang=[]

# CODE HERE WKWK
for index, row in df.iterrows():
  # inisialisasi variabel untuk tiap isi kolomnya
  angkatan = row['NPM'][:2]
  tgl_lahir = row['Tanggal Lahir']
  tgl_yudis = row['Tanggal Yudisium']
  tmp_lahir = row['Tempat Lahir']
  gol_ukt = row['Golongan UKT']  

  # inisialisasi tgl sem6 dan tgl yudisium
  # berdasarkan angkatan
  if angkatan == '14':
    sem6 = '02/01/2017'
    yudis = '07/01/2018'
  elif angkatan == '15':
    sem6 = '02/01/2018'
    yudis = '07/01/2019'
  elif angkatan == '16':
    sem6 = '02/01/2019'
    yudis = '07/01/2020'

  # memanggil fungsi untuk menghitung usia
  age = calculateDate(tgl_lahir, sem6)

  # memanggil fungsi untuk mengetahui keputusan
  decision = calculateDate(tgl_yudis, yudis) 

  # menambahkan ke array usia
  usia.append(age[0])

  # menambahkan ke array keputusan
  keputusan.append(decision[1])

  # inisialisasi variabel apakah tempat lahir
  # mengandung kata 'Surabaya'
  lahir = re.search(r"Surabaya", tmp_lahir)

  if lahir == None:
    lahir = 'Luar Surabaya'
  else:
    lahir = 'Surabaya'
  
  # menambahkan ke array asal
  asal.append(lahir)

  # menambah angkatan
  # tujuan visualisasi
  ang.append(angkatan)

# %%
# memasukkan data array ke dalam kolom baru di df
df['Usia'] = np.array(usia)
df['Asal'] = np.array(asal)
df['Keputusan'] = np.array(keputusan)
df['Angkatan'] = np.array(ang)

# %%
df
# Out:
#             NPM Jenis Kelamin  ...  Keputusan Angkatan
# 0    1434010001     Laki-laki  ...  Terlambat       14
# 1    1434010002     Laki-laki  ...  Terlambat       14
# 2    1434010003     Laki-laki  ...  Terlambat       14
# 3    1434010004     Laki-laki  ...  Terlambat       14
# 4    1434010005     Laki-laki  ...      Tepat       14
# ..          ...           ...  ...        ...      ...
# 400  1635010076     Laki-laki  ...  Terlambat       16
# 401  1635010077     Perempuan  ...  Terlambat       16
# 402  1635010078     Laki-laki  ...  Terlambat       16
# 403  1635010079     Laki-laki  ...  Terlambat       16
# 404  1635010080     Perempuan  ...  Terlambat       16
#
# [405 rows x 24 columns]

# %% [markdown]
# ##### Statistika Kelulusan Fasilkom

# %%
df.groupby(['Keputusan','Angkatan']).size()
# Out:
# Keputusan  Angkatan
# Tepat      14           26
#            15           58
#            16           48
# Terlambat  14          145
#            15           88
#            16           40
# dtype: int64

# %%
df2 = pd.DataFrame(data={'Angkatan': ['2014', '2015', '2016', '2014', '2015', '2016'], 
                        'Keputusan': ['Tepat Waktu', 'Tepat Waktu', 'Tepat Waktu', 'Jumlah Mahasiswa Lulus', 'Jumlah Mahasiswa Lulus', 'Jumlah Mahasiswa Lulus'], 
                        'Persen': [9, 24, 27, 58, 60, 49]
                         })

df2
# Out:
#   Angkatan               Keputusan  Persen
# 0     2014             Tepat Waktu       9
# 1     2015             Tepat Waktu      24
# 2     2016             Tepat Waktu      27
# 3     2014  Jumlah Mahasiswa Lulus      58
# 4     2015  Jumlah Mahasiswa Lulus      60
# 5     2016  Jumlah Mahasiswa Lulus      49

# %%
kep_set = set(df2['Keputusan'])

plt.figure()
for kep in kep_set:
     selected_data = df2.loc[df2['Keputusan'] == kep]
     plt.plot(selected_data['Angkatan'], selected_data['Persen'], label=kep)
     
plt.legend()
plt.ylabel('Persen (%)')
plt.xlabel('Angkatan')
plt.title('Persentase Kelulusan Mahasiswa Tiap Angkatan')
plt.show()

# %%
# menghapus kolom yang nggak dibutuhkan lagi
df = df.drop('NPM', axis=1)
df = df.drop('Tempat Lahir', axis=1)
df = df.drop('Tanggal Lahir', axis=1)
df = df.drop('Tanggal Yudisium', axis=1)
df = df.drop('Angkatan', axis=1)

# %% [markdown]
# ##### Organisasi

# %%
df['Organisasi'].describe()
# Out:
# count     107
# unique      1
# top        Ya
# freq      107
# Name: Organisasi, dtype: object

# %%
df['Organisasi'].isnull().sum()
# Out:
# 298

# %%
df.loc[df['Organisasi'].isna(), 'Organisasi'] = 'Tidak'
df['Organisasi']
# Out:
# 0      Tidak
# 1      Tidak
# 2      Tidak
# 3      Tidak
# 4      Tidak
#        ...
# 400    Tidak
# 401    Tidak
# 402       Ya
# 403       Ya
# 404       Ya
# Name: Organisasi, Length: 405, dtype: object

# %%
org = df['Organisasi'].groupby(df['Organisasi']).count()

plt.bar(org.index, org)
plt.bar
# Out:
# <function matplotlib.pyplot.bar>

# %% [markdown]
# ##### Memperbaiki susunan kolom

# %%
df = df[['Jurusan', 'Jenis Kelamin', 'Usia', 'Asal', 'Jalur Masuk', 'Golongan UKT', 'Organisasi', 'IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5', 'SKS 1', 'SKS 2', 'SKS 3', 'SKS 4', 'SKS 5', 'SKS 6', 'Keputusan']]

# %%
df
# Out:
#               Jurusan Jenis Kelamin  Usia  ... SKS 5 SKS 6  Keputusan
# 0         Informatika     Laki-laki    20  ...    23    19  Terlambat
# 1         Informatika     Laki-laki    20  ...    23    16  Terlambat
# 2         Informatika     Laki-laki    20  ...    23    19  Terlambat
# 3         Informatika     Laki-laki    21  ...    23    19  Terlambat
# 4         Informatika     Laki-laki    21  ...    23    16      Tepat
# ..                ...           ...   ...  ...   ...   ...        ...
# 400  Sistem Informasi     Laki-laki    20  ...    20    23  Terlambat
# 401  Sistem Informasi     Perempuan    20  ...    20    23  Terlambat
# 402  Sistem Informasi     Laki-laki    21  ...    20    23  Terlambat
# 403  Sistem Informasi     Laki-laki    20  ...    23    23  Terlambat
# 404  Sistem Informasi     Perempuan    20  ...    23    20  Terlambat
#
# [405 rows x 19 columns]

# %% [markdown]
# ##### Menyimpan hasil data preparation

# %%
df.to_pickle('data.pkl')

# %% [markdown]
# ### Data Exploratory

# %%
df
# Out:
#               Jurusan Jenis Kelamin  Usia  ... SKS 5 SKS 6  Keputusan
# 0         Informatika     Laki-laki    20  ...    23    19  Terlambat
# 1         Informatika     Laki-laki    20  ...    23    16  Terlambat
# 2         Informatika     Laki-laki    20  ...    23    19  Terlambat
# 3         Informatika     Laki-laki    21  ...    23    19  Terlambat
# 4         Informatika     Laki-laki    21  ...    23    16      Tepat
# ..                ...           ...   ...  ...   ...   ...        ...
# 400  Sistem Informasi     Laki-laki    20  ...    20    23  Terlambat
# 401  Sistem Informasi     Perempuan    20  ...    20    23  Terlambat
# 402  Sistem Informasi     Laki-laki    21  ...    20    23  Terlambat
# 403  Sistem Informasi     Laki-laki    20  ...    23    23  Terlambat
# 404  Sistem Informasi     Perempuan    20  ...    23    20  Terlambat
#
# [405 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# Jurusan          0
# Jenis Kelamin    0
# Usia             0
# Asal             0
# Jalur Masuk      0
# Golongan UKT     0
# Organisasi       0
# IPS 1            0
# IPS 2            0
# IPS 3            0
# IPS 4            0
# IPS 5            0
# SKS 1            0
# SKS 2            0
# SKS 3            0
# SKS 4            0
# SKS 5            0
# SKS 6            0
# Keputusan        0
# dtype: int64

# %% [markdown]
# ##### Keputusan

# %%
df['Keputusan'].value_counts()
# Out:
# Terlambat    273
# Tepat        132
# Name: Keputusan, dtype: int64

# %%
kep = df['Keputusan'].groupby(df['Keputusan']).count()

plt.bar(kep.index, kep)
plt.show()

# %%
df['Keputusan'].replace('Terlambat', 0, inplace=True)
df['Keputusan'].replace('Tepat', 1, inplace=True)

# %%
def grafik_kelulusan(atribut):
  terlambat = df[df['Keputusan'] == 0][atribut].value_counts()
  tepat = df[df['Keputusan'] == 1][atribut].value_counts()
  data = pd.DataFrame([terlambat, tepat])
  data.index=['Terlambat', 'Tepat']
  data.T.plot(kind='bar', stacked=True, title='Kelulusan')
  return data.head()

# %% [markdown]
# ##### Jurusan

# %%
df['Jurusan'].value_counts()
# Out:
# Informatika         256
# Sistem Informasi    149
# Name: Jurusan, dtype: int64

# %%
jur = df['Jurusan'].groupby(df['Jurusan']).count()

plt.bar(jur.index, jur)
plt.show()

# %%
grafik_kelulusan('Jurusan')
# Out:
#            Informatika  Sistem Informasi
# Terlambat          184                89
# Tepat               72                60

# %%
print(sns.catplot(x='Jurusan', y='Keputusan', kind ='bar', data=df))
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x7fc07ca094d0>

# %% [markdown]
# ##### Jenis Kelamin

# %%
df['Jenis Kelamin'].value_counts()
# Out:
# Laki-laki    283
# Perempuan    122
# Name: Jenis Kelamin, dtype: int64

# %%
jk = df['Jenis Kelamin'].groupby(df['Jenis Kelamin']).count()

plt.bar(jk.index, jk)
plt.show()

# %%
grafik_kelulusan('Jenis Kelamin')
# Out:
#            Laki-laki  Perempuan
# Terlambat        221         52
# Tepat             62         70

# %%
sns.catplot(x='Jenis Kelamin', y='Keputusan', kind ='bar', data=df)

# %% [markdown]
# ##### Usia

# %%
df['Usia'].value_counts().sort_index()
# Out:
# 19     20
# 20    247
# 21    117
# 22     17
# 23      2
# 24      2
# Name: Usia, dtype: int64

# %%
umur = df['Usia'].groupby(df['Usia']).count().sort_values()

plt.bar(umur.index, umur)
plt.show()

# %%
grafik_kelulusan('Usia')
# Out:
#              19     20    21    22   23   24
# Terlambat  12.0  159.0  84.0  14.0  2.0  2.0
# Tepat       8.0   88.0  33.0   3.0  NaN  NaN

# %%
sns.catplot(x='Usia', y='Keputusan', kind='bar', data=df)

# %% [markdown]
# ##### Asal

# %%
df['Asal'].value_counts()
# Out:
# Luar Surabaya    229
# Surabaya         176
# Name: Asal, dtype: int64

# %%
tot_asal = df['Asal'].groupby(df['Asal']).count()

plt.bar(tot_asal.index, tot_asal)
plt.show()

# %%
grafik_kelulusan('Asal')
# Out:
#            Luar Surabaya  Surabaya
# Terlambat            152       121
# Tepat                 77        55

# %%
sns.catplot(x='Asal', y='Keputusan', kind='bar', data=df)

# %% [markdown]
# ##### Jalur Masuk

# %%
df['Jalur Masuk'].value_counts()
# Out:
# SBMPTN     193
# Mandiri    155
# SNMPTN      57
# Name: Jalur Masuk, dtype: int64

# %%
jm = df['Jalur Masuk'].groupby(df['Jalur Masuk']).count()

plt.bar(jm.index, jm)
plt.show()

# %%
grafik_kelulusan('Jalur Masuk')
# Out:
#            SBMPTN  Mandiri  SNMPTN
# Terlambat     126      108      39
# Tepat          67       47      18

# %%
sns.catplot(x='Jalur Masuk', y='Keputusan', kind='bar', data=df)

# %% [markdown]
# ##### Golongan UKT

# %%
df['Golongan UKT'].value_counts()
# Out:
# 2    118
# 1     59
# 6     53
# 4     49
# 3     45
# 5     44
# 8     19
# 7     18
# Name: Golongan UKT, dtype: int64

# %%
ukt = df['Golongan UKT'].groupby(df['Golongan UKT']).count().sort_values()

plt.bar(ukt.index, ukt)
plt.show()

# %%
grafik_kelulusan('Golongan UKT')
# Out:
#             1   2   3   4   5   6   7   8
# Terlambat  50  91  19  26  27  31  16  13
# Tepat       9  27  26  23  17  22   2   6

# %%
sns.catplot(x='Golongan UKT', y='Keputusan', kind='bar', data=df)

# %% [markdown]
# ##### Organisasi

# %%
df['Organisasi'].value_counts()
# Out:
# Tidak    298
# Ya       107
# Name: Organisasi, dtype: int64

# %%
org = df['Organisasi'].groupby(df['Organisasi']).count()

plt.bar(org.index, org)
plt.bar
# Out:
# <function matplotlib.pyplot.bar>

# %%
grafik_kelulusan('Organisasi')
# Out:
#            Tidak  Ya
# Terlambat    215  58
# Tepat         83  49

# %%
sns.catplot(x='Organisasi', y='Keputusan', kind='bar', data=df)

# %% [markdown]
# ##### IPS

# %%
sns.boxplot(y= df['IPS 1'], palette="RdBu"), 
sns.swarmplot(y= df['IPS 1'], color=".25")

# %%
sns.scatterplot(data=df, x=df['IPS 1'], y=df['Keputusan'])

# %%
sns.boxplot(y= df['IPS 2'], palette="RdBu"), 
sns.swarmplot(y= df['IPS 2'], color=".25")

# %%
sns.scatterplot(data=df, x=df['IPS 2'], y=df['Keputusan'])

# %%
sns.boxplot(y= df['IPS 3'], palette="RdBu"), 
sns.swarmplot(y= df['IPS 3'], color=".25")

# %%
sns.scatterplot(data=df, x=df['IPS 3'], y=df['Keputusan'])

# %%
sns.boxplot(y= df['IPS 4'], palette="RdBu"), 
sns.swarmplot(y= df['IPS 4'], color=".25")

# %%
sns.scatterplot(data=df, x=df['IPS 4'], y=df['Keputusan'])

# %%
sns.boxplot(y= df['IPS 5'], palette="RdBu"), 
sns.swarmplot(y= df['IPS 5'], color=".25")

# %%
sns.scatterplot(data=df, x=df['IPS 5'], y=df['Keputusan'])

# %% [markdown]
# ### Correlation

# %%
df_encode = df

# %% [markdown]
# ##### Encoding

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.2.2-py2.py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 4.5 MB/s
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.19.5)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.2.2

# %%
import category_encoders as ce

encoder= ce.OrdinalEncoder(mapping=[{'col':'Jurusan', 'mapping':{'Informatika':0, 'Sistem Informasi':1}},
                                    {'col':'Jenis Kelamin', 'mapping':{'Laki-laki':0, 'Perempuan':1}},
                                    {'col':'Asal', 'mapping':{'Surabaya':0, 'Luar Surabaya':1}},
                                    {'col':'Jalur Masuk', 'mapping':{'SNMPTN':0,'SBMPTN':1,'Mandiri':2}},
                                    {'col':'Organisasi', 'mapping':{'Ya':0, 'Tidak':1}}
                                    ])

df_encode = encoder.fit_transform(df_encode)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_encode
# Out:
#      Jurusan  Jenis Kelamin  Usia  Asal  ...  SKS 4  SKS 5  SKS 6  Keputusan
# 0          0              0    20     1  ...     22     23     19          0
# 1          0              0    20     0  ...     23     23     16          0
# 2          0              0    20     0  ...     23     23     19          0
# 3          0              0    21     1  ...     23     23     19          0
# 4          0              0    21     0  ...     22     23     16          1
# ..       ...            ...   ...   ...  ...    ...    ...    ...        ...
# 400        1              0    20     0  ...     22     20     23          0
# 401        1              1    20     0  ...     22     20     23          0
# 402        1              0    21     0  ...     22     20     23          0
# 403        1              0    20     0  ...     22     23     23          0
# 404        1              1    20     0  ...     22     23     20          0
#
# [405 rows x 19 columns]

# %% [markdown]
# ##### Correlation

# %%
def data_correlation(data):
  correlation = data.corr()
  fig = plt.gcf()
  figsize = fig.get_size_inches()
  fig.set_size_inches(figsize*5)
  sns.heatmap(correlation, annot=True, cbar=True, cmap="RdYlGn")

# %%
data_correlation(df_encode)

# %%
df_encode.corr()
# Out:
#                 Jurusan  Jenis Kelamin      Usia  ...     SKS 5     SKS 6  Keputusan
# Jurusan        1.000000       0.124056 -0.038652  ...  0.279711  0.397586   0.124936
# Jenis Kelamin  0.124056       1.000000 -0.157161  ...  0.028310  0.199317   0.347179
# Usia          -0.038652      -0.157161  1.000000  ...  0.003953 -0.109770  -0.120954
# Asal          -0.043893       0.032758  0.140770  ...  0.050468 -0.020442   0.025111
# Jalur Masuk   -0.052974      -0.090936 -0.036239  ...  0.008721 -0.065012  -0.022720
# Golongan UKT   0.121469       0.112226 -0.080647  ... -0.008583  0.224223   0.108291
# Organisasi    -0.158337      -0.216879  0.144792  ... -0.075034 -0.220184  -0.168773
# IPS 1          0.183981       0.221903  0.007487  ...  0.155131  0.101448   0.262119
# IPS 2          0.036358       0.346062 -0.071372  ...  0.057555  0.060944   0.319122
# IPS 3          0.097814       0.342913 -0.134287  ...  0.029450  0.208565   0.344315
# IPS 4         -0.189115       0.305261 -0.066641  ...  0.209524  0.134668   0.321323
# IPS 5         -0.064702       0.156970 -0.040521  ...  0.073623  0.123240   0.355547
# SKS 1         -0.903273      -0.147237  0.070996  ... -0.198343 -0.420567  -0.157248
# SKS 2          0.076089      -0.155416  0.075843  ...  0.078193 -0.392120  -0.131250
# SKS 3         -0.292799       0.112510 -0.010152  ... -0.105912 -0.153570   0.103993
# SKS 4         -0.298295      -0.085312  0.127075  ... -0.035760 -0.056753  -0.038695
# SKS 5          0.279711       0.028310  0.003953  ...  1.000000  0.010516   0.025620
# SKS 6          0.397586       0.199317 -0.109770  ...  0.010516  1.000000   0.257722
# Keputusan      0.124936       0.347179 -0.120954  ...  0.025620  0.257722   1.000000
#
# [19 rows x 19 columns]

# %%
df_encode[['IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5']].corrwith(df_encode['Keputusan'])
# Out:
# IPS 1    0.262119
# IPS 2    0.319122
# IPS 3    0.344315
# IPS 4    0.321323
# IPS 5    0.355547
# dtype: float64

# %%
# data_correlation(df_encode[['IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5', 'Keputusan']])
sns.heatmap(df_encode[['IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5', 'Keputusan']].corr(), annot=True, cbar=True, cmap="RdYlGn")

# %%
df_encode[['SKS 1', 'SKS 2', 'SKS 3', 'SKS 4', 'SKS 5', 'SKS 6']].corrwith(df_encode['Keputusan'])
# Out:
# SKS 1   -0.157248
# SKS 2   -0.131250
# SKS 3    0.103993
# SKS 4   -0.038695
# SKS 5    0.025620
# SKS 6    0.257722
# dtype: float64

# %%
sns.heatmap(df_encode[['SKS 1', 'SKS 2', 'SKS 3', 'SKS 4', 'SKS 5', 'SKS 6', 'Keputusan']].corr(), annot=True, cbar=True, cmap="RdYlGn")

# %% [markdown]
# ### Modelling dan Evaluation

# %%
data = df_encode.drop(columns='Keputusan')
label = df_encode['Keputusan']

# %%
data
# Out:
#      Jurusan  Jenis Kelamin  Usia  Asal  ...  SKS 3  SKS 4  SKS 5  SKS 6
# 0          0              0    20     1  ...     23     22     23     19
# 1          0              0    20     0  ...     23     23     23     16
# 2          0              0    20     0  ...     23     23     23     19
# 3          0              0    21     1  ...     23     23     23     19
# 4          0              0    21     0  ...     23     22     23     16
# ..       ...            ...   ...   ...  ...    ...    ...    ...    ...
# 400        1              0    20     0  ...     23     22     20     23
# 401        1              1    20     0  ...     23     22     20     23
# 402        1              0    21     0  ...     23     22     20     23
# 403        1              0    20     0  ...     23     22     23     23
# 404        1              1    20     0  ...     23     22     23     20
#
# [405 rows x 18 columns]

# %%
data.dtypes
# Out:
# Jurusan            int64
# Jenis Kelamin      int64
# Usia               int64
# Asal               int64
# Jalur Masuk        int64
# Golongan UKT       int64
# Organisasi         int64
# IPS 1            float64
# IPS 2            float64
# IPS 3            float64
# IPS 4            float64
# IPS 5            float64
# SKS 1              int64
# SKS 2              int64
# SKS 3              int64
# SKS 4              int64
# SKS 5              int64
# SKS 6              int64
# dtype: object

# %%
label
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 400    0
# 401    0
# 402    0
# 403    0
# 404    0
# Name: Keputusan, Length: 405, dtype: int64

# %%
data.describe()
# Out:
#           Jurusan  Jenis Kelamin  ...       SKS 5       SKS 6
# count  405.000000     405.000000  ...  405.000000  405.000000
# mean     0.367901       0.301235  ...   22.360494   21.219753
# std      0.482831       0.459362  ...    1.526473    2.762659
# min      0.000000       0.000000  ...   13.000000   10.000000
# 25%      0.000000       0.000000  ...   22.000000   19.000000
# 50%      0.000000       0.000000  ...   23.000000   22.000000
# 75%      1.000000       1.000000  ...   23.000000   23.000000
# max      1.000000       1.000000  ...   25.000000   24.000000
#
# [8 rows x 18 columns]

# %% [markdown]
# #### Skenario 1: NB

# %%
X_train_s1, X_test_s1, y_train_s1, y_test_s1 = train_test_split(
    data,
    label,
    test_size = 0.3,
    random_state=180,
    stratify=label
)

# %%
model_s1 = GaussianNB()
model_s1.fit(X_train_s1, y_train_s1)  
prediction_s1 = model_s1.predict(X_test_s1)
  
# print classification report
print('Confusion Matrix \n', confusion_matrix(y_test_s1, prediction_s1))
print('\n Accuracy : ', accuracy_score(y_test_s1, prediction_s1))
print('\n Classification Report \n', classification_report(y_test_s1, prediction_s1))
print('AUC : ', roc_auc_score(y_test_s1, prediction_s1))
# Out:
# Confusion Matrix
#  [[54 28]
#  [ 8 32]]
#
#  Accuracy :  0.7049180327868853
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.87      0.66      0.75        82
#            1       0.53      0.80      0.64        40
#
#     accuracy                           0.70       122
#    macro avg       0.70      0.73      0.70       122
# weighted avg       0.76      0.70      0.71       122
#
# AUC :  0.7292682926829268

# %% [markdown]
# #### Skenario 2: NB + SMOTE

# %%
from sklearn.preprocessing import StandardScaler

data_s2 = StandardScaler().fit_transform(data)
print(data_s2)
# Out:
# [[-0.76290973 -0.65657856 -0.50559183 ... -0.29625903  0.41946194
#   -0.80447822]
#  [-0.76290973 -0.65657856 -0.50559183 ...  0.58598294  0.41946194
#   -1.89173187]
#  [-0.76290973 -0.65657856 -0.50559183 ...  0.58598294  0.41946194
#   -0.80447822]
#  ...
#  [ 1.31077107 -0.65657856  0.90657846 ... -0.29625903 -1.54828422
#    0.64519332]
#  [ 1.31077107 -0.65657856 -0.50559183 ... -0.29625903  0.41946194
#    0.64519332]
#  [ 1.31077107  1.52304699 -0.50559183 ... -0.29625903  0.41946194
#   -0.44206033]]

# %%
X_train_s2, X_test_s2, y_train_s2, y_test_s2 = train_test_split(
    data_s2,
    label,
    test_size = 0.3,
    random_state=180,
    stratify=label
)

# %%
print("Sebelum SMOTE, label '0': {}".format(sum(y_train_s2 == 0)))
print("Sebelum SMOTE, label '1': {} \n".format(sum(y_train_s2 == 1)))
  
# apply SMOTE
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_smote, y_train_smote = sm.fit_sample(X_train_s2, y_train_s2)

print("Sesudah SMOTE, label '0': {}".format(sum(y_train_smote == 0)))
print("Sesudah SMOTE, label '1': {}".format(sum(y_train_smote == 1)))
# Out:
# Sebelum SMOTE, label '0': 191
# Sebelum SMOTE, label '1': 92
#
# Sesudah SMOTE, label '0': 191
# Sesudah SMOTE, label '1': 191
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
model_s2 = GaussianNB()
model_s2.fit(X_train_smote, y_train_smote)  
prediction_s2 = model_s2.predict(X_test_s2)
  
# print classification report
print('Confusion Matrix \n', confusion_matrix(y_test_s2, prediction_s2))
print('\n Accuracy : ', accuracy_score(y_test_s2, prediction_s2))
print('\n Classification Report \n', classification_report(y_test_s2, prediction_s2))
print('AUC : ', roc_auc_score(y_test_s2, prediction_s2))
# Out:
# Confusion Matrix
#  [[51 31]
#  [ 5 35]]
#
#  Accuracy :  0.7049180327868853
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.91      0.62      0.74        82
#            1       0.53      0.88      0.66        40
#
#     accuracy                           0.70       122
#    macro avg       0.72      0.75      0.70       122
# weighted avg       0.79      0.70      0.71       122
#
# AUC :  0.7484756097560976

# %% [markdown]
# #### Skenario 3: NB + PCA

# %% [markdown]
# PCA:
# 1. Normalisasi data
# 2. Hitung Covarian Matrix
# 3. Hitung eigenvalue
# 4. Hitung eigenvector
# 5. Tentukan komponen baru

# %% [markdown]
# ##### Standarisasi

# %%
from sklearn.preprocessing import StandardScaler

data_s3 = StandardScaler().fit_transform(data)
data_s3 = pd.DataFrame(data_s3)
print(data_s3)
# Out:
#            0         1         2   ...        15        16        17
# 0   -0.762910 -0.656579 -0.505592  ... -0.296259  0.419462 -0.804478
# 1   -0.762910 -0.656579 -0.505592  ...  0.585983  0.419462 -1.891732
# 2   -0.762910 -0.656579 -0.505592  ...  0.585983  0.419462 -0.804478
# 3   -0.762910 -0.656579  0.906578  ...  0.585983  0.419462 -0.804478
# 4   -0.762910 -0.656579  0.906578  ... -0.296259  0.419462 -1.891732
# ..        ...       ...       ...  ...       ...       ...       ...
# 400  1.310771 -0.656579 -0.505592  ... -0.296259 -1.548284  0.645193
# 401  1.310771  1.523047 -0.505592  ... -0.296259 -1.548284  0.645193
# 402  1.310771 -0.656579  0.906578  ... -0.296259 -1.548284  0.645193
# 403  1.310771 -0.656579 -0.505592  ... -0.296259  0.419462  0.645193
# 404  1.310771  1.523047 -0.505592  ... -0.296259  0.419462 -0.442060
#
# [405 rows x 18 columns]

# %%
import pickle

std_filename = 'scaler.pkl'
pickle.dump(data_s3, open(std_filename, 'wb'))

# %% [markdown]
# ##### Covarian Matrix

# %%
# Menghitung Covariance Matrix

data_s3_mean = np.mean(data_s3, axis=0)
cov_mat = (data_s3 - data_s3_mean).T.dot((data_s3 - data_s3_mean)) / (data_s3.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
#           0         1         2   ...        15        16        17
# 0   1.002475  0.124363 -0.038748  ... -0.299033  0.280403  0.398570
# 1   0.124363  1.002475 -0.157550  ... -0.085524  0.028380  0.199811
# 2  -0.038748 -0.157550  1.002475  ...  0.127390  0.003963 -0.110041
# 3  -0.044001  0.032840  0.141119  ...  0.040095  0.050593 -0.020492
# 4  -0.053105 -0.091161 -0.036329  ... -0.082979  0.008743 -0.065173
# 5   0.121769  0.112504 -0.080847  ... -0.094268 -0.008605  0.224778
# 6  -0.158729 -0.217416  0.145150  ...  0.029375 -0.075219 -0.220729
# 7   0.184436  0.222452  0.007505  ... -0.013572  0.155515  0.101699
# 8   0.036448  0.346918 -0.071549  ... -0.019364  0.057697  0.061095
# 9   0.098056  0.343762 -0.134620  ...  0.153272  0.029523  0.209082
# 10 -0.189583  0.306016 -0.066806  ...  0.087803  0.210043  0.135001
# 11 -0.064863  0.157358 -0.040621  ... -0.055195  0.073806  0.123545
# 12 -0.905509 -0.147601  0.071172  ...  0.386787 -0.198834 -0.421608
# 13  0.076277 -0.155801  0.076030  ... -0.254546  0.078386 -0.393091
# 14 -0.293523  0.112789 -0.010178  ... -0.075411 -0.106174 -0.153950
# 15 -0.299033 -0.085524  0.127390  ...  1.002475 -0.035848 -0.056894
# 16  0.280403  0.028380  0.003963  ... -0.035848  1.002475  0.010542
# 17  0.398570  0.199811 -0.110041  ... -0.056894  0.010542  1.002475
#
# [18 rows x 18 columns]

# %% [markdown]
# ##### Eigenvalue, Eigenvector

# %%
# Menghitung Eigen Value dan Eigen Vector

eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-9.79019986e-02 -5.50368383e-01 -1.32444370e-01  7.03516624e-01
#    1.74700043e-01  1.95536206e-02  3.64406851e-02  1.22074620e-01
#    9.44939278e-02  3.00605356e-01  9.83345267e-02  5.90026980e-02
#    2.25361467e-02  6.65156292e-02  9.98058472e-03  5.14154657e-02
#    8.78977900e-02 -7.41850076e-03]
#  [-2.68616039e-01 -7.30152535e-02  1.24371137e-01  8.75975301e-03
#   -1.54888433e-01  8.21876646e-02 -5.54938129e-01  1.52972003e-01
#   -1.15983460e-01  1.42404767e-01]]
#
# Eigenvalues
# [3.67493045 2.64114247 1.82770744 0.05902563 1.32486667 0.17563494
#  1.16999506 0.27356185 0.3338162  0.4065665  0.43362576 1.05473086
#  0.96291414 0.87961384 0.6123115  0.78583    0.73605686 0.6922243 ]

# %%
# Membuat tuple eigenvalue, eigenvector menjadi berpasangan
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Mengurutkan pasangan eigenvalue, eigenvector dari tinggi ke rendah
eig_pairs.sort(key=lambda x: x[0], reverse=True)

# Ngeprint eigenvalue dari tinggi ke rendah
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 3.6749304543703154
# 2.641142468782359
# 1.8277074359683705
# 1.3248666702300738
# 1.1699950594462307
# 1.054730857044203
# 0.9629141406711705
# 0.879613840329956
# 0.7858300026654923
# 0.7360568595083337
# 0.6922243006798076
# 0.6123114974341037
# 0.43362575800845654
# 0.4065665027988336
# 0.33381619509512767
# 0.273561845268443
# 0.1756349404097771
# 0.05902562673449818

# %%
# Menghitung jumlah variasi data berdasarkan jumlah komponennya

tot = sum(eig_vals) # tot berjumlah 100
var_exp = [(i / tot)*100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
cum_var_exp
# Out:
# array([ 20.36586973,  35.00265379,  45.13151255,  52.47370919,
#         58.95763243,  64.80278011,  70.13909442,  75.01377194,
#         79.36871462,  83.44782259,  87.28401762,  90.67734882,
#         93.08043258,  95.33355833,  97.18351365,  98.69954912,
#         99.67288953, 100.        ])

# %%
plt.bar(range(1,19), var_exp, alpha=0.5, align='center', label='Jumlah PCs')
plt.step(range(1,19),cum_var_exp, where= 'mid', label='Variance')
plt.ylabel('Variansi Data')
plt.xlabel('Principal components')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ##### Menentukan komponen baru

# %%
# Perhitungan matematika

eigvectors_sorted= [eig_pairs[index][1] for index in range(len(eig_vals))]

D_reduce = np.array(eigvectors_sorted[0:14])   # Mengurangi dari 18 menjadi 14 dimensi
data_D = np.dot(data_s3,D_reduce.T)   # memproyeksikan data asli ke dalam dimensi komponen utama
data_reduced_pca = pd.DataFrame(data_D)  # convert ke dataframe baru

data_reduced_pca
# Out:
#            0         1         2   ...        11        12        13
# 0   -1.501513  1.763439 -1.662613  ...  0.027146 -0.445357 -0.413395
# 1    1.884344  1.488483 -1.172314  ...  0.183743  0.723251  0.804238
# 2    0.168572  1.541274 -0.749098  ... -0.078834  0.858234  0.126353
# 3    0.496967  1.742001 -1.220448  ... -0.656836  0.304316  0.013271
# 4    0.298060  1.952945 -1.955467  ...  0.932640  0.533296  0.563651
# ..        ...       ...       ...  ...       ...       ...       ...
# 400  1.499090 -1.351521 -0.632539  ... -1.236834  0.201255  0.699569
# 401  0.659517 -1.373098 -0.187708  ... -0.648194  1.149772  0.775002
# 402 -0.178007 -1.354005  0.704433  ...  1.055643  0.025055  0.666912
# 403  0.518217 -2.016608  0.064749  ... -0.392335  0.309151  0.736749
# 404 -1.280005 -1.406751 -0.113879  ...  0.871118  0.746935  0.827441
#
# [405 rows x 14 columns]

# %%
# menyimpan weight untuk data selanjutnya
import pickle

red_filename = 'reduce.pkl'
pickle.dump(D_reduce, open(red_filename, 'wb'))

# %%
X_train_s3, X_test_s3, y_train_s3, y_test_s3 = train_test_split(
    data_reduced_pca,
    label,
    test_size = 0.3,
    random_state=180,
    stratify=label
)

# %%
model_s3 = GaussianNB()
model_s3.fit(X_train_s3, y_train_s3)
prediction_s3 = model_s3.predict(X_test_s3)

# %%
print("Confusion Matrix \n",confusion_matrix(y_test_s3,prediction_s3))
print("\n Accuracy",accuracy_score(y_test_s3,prediction_s3))
print("\n Classification Report \n",classification_report(y_test_s3,prediction_s3))
print("\n ROC AUC",roc_auc_score(y_test_s3,prediction_s3))
# Out:
# Confusion Matrix
#  [[68 14]
#  [11 29]]
#
#  Accuracy 0.7950819672131147
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        82
#            1       0.67      0.72      0.70        40
#
#     accuracy                           0.80       122
#    macro avg       0.77      0.78      0.77       122
# weighted avg       0.80      0.80      0.80       122
#
#
#  ROC AUC 0.7771341463414634

# %% [markdown]
# #### Skenario 4: NB + SMOTE + PCA

# %%
from sklearn.preprocessing import StandardScaler

data_s4 = StandardScaler().fit_transform(data)
print(data_s4)
# Out:
# [[-0.76290973 -0.65657856 -0.50559183 ... -0.29625903  0.41946194
#   -0.80447822]
#  [-0.76290973 -0.65657856 -0.50559183 ...  0.58598294  0.41946194
#   -1.89173187]
#  [-0.76290973 -0.65657856 -0.50559183 ...  0.58598294  0.41946194
#   -0.80447822]
#  ...
#  [ 1.31077107 -0.65657856  0.90657846 ... -0.29625903 -1.54828422
#    0.64519332]
#  [ 1.31077107 -0.65657856 -0.50559183 ... -0.29625903  0.41946194
#    0.64519332]
#  [ 1.31077107  1.52304699 -0.50559183 ... -0.29625903  0.41946194
#   -0.44206033]]

# %%
X_train_s4, X_test_s4, y_train_s4, y_test_s4 = train_test_split(
    data_s4,
    label,
    test_size = 0.3,
    random_state=180,
    stratify=label
)

# %% [markdown]
# ##### SMOTE

# %%
# apply SMOTE
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_smote_s4, y_train_smote_s4 = sm.fit_sample(X_train_s4, y_train_s4)

print("Setelah SMOTE, label '0': {}".format(sum(y_train_smote_s4 == 0)))
print("Setelah SMOTE, label '1': {}".format(sum(y_train_smote_s4 == 1)))
# Out:
# Setelah SMOTE, label '0': 191
# Setelah SMOTE, label '1': 191
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##### Covarian Matrix

# %%
# Menghitung Covariance Matrix

data_s4_mean = np.mean(X_train_smote_s4, axis=0)
cov_mat = (X_train_smote_s4 - data_s4_mean).T.dot((X_train_smote_s4 - data_s4_mean)) / (X_train_smote_s4.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
# [[ 1.00551399e+00  1.53022866e-01 -3.52445832e-02 -3.69890137e-02
#   -2.59069453e-02  1.55041274e-01 -1.34652634e-01  9.09649046e-02
#    6.00711701e-03  2.24525796e-02 -2.04155618e-01 -6.83588041e-02
#    3.68499669e-02 -4.68651274e-02 -2.30286267e-01  2.49167711e-01
#   -1.44714021e-01 -4.78787002e-01  5.64627362e-03  6.06831744e-02
#   -9.40966336e-02 -3.72104794e-01 -4.84340167e-01 -1.92060250e-01
#    2.30169695e-02 -3.79229556e-02]
#  [ 1.95876690e-02  1.54009761e-01 -1.77756073e-01 -1.19505603e-01
#    9.07379926e-02  4.97264772e-02  3.75919007e-01  1.63979127e-01
#   -8.92617310e-03 -6.78139950e-02 -3.52580889e-02  2.01903488e-01
#    1.58289462e-01  5.27900253e-02 -4.68401333e-01  4.58699861e-01
#   -2.83476339e-01  4.07939988e-01]
#  [ 2.73048623e-01  2.94666488e-01  3.37732195e-01 -1.02021066e-01
#   -2.63509490e-02  1.51173110e-01  1.28335411e-01  3.00698164e-01
#   -3.20167545e-01  1.17845248e-01  2.35795446e-01 -5.54739660e-02
#    4.57261912e-02  5.25248522e-01 -1.85934862e-01 -2.58521096e-01
#    8.06605206e-02 -1.50824985e-01]]
#
# Eigenvalues
# [3.45906926 2.73322662 1.84326716 1.32623017 0.05661134 0.15741672
#  0.24198192 0.25897945 0.35917705 0.39057903 0.94762968 0.88118663
#  0.80300432 0.5674238  0.58273228 0.63542687 0.68014392 0.7495048 ]

# %%
# Membuat tuple eigenvalue, eigenvector menjadi berpasangan
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Mengurutkan pasangan eigenvalue, eigenvector dari tinggi ke rendah
eig_pairs.sort(key=lambda x: x[0], reverse=True)

# Ngeprint eigenvalue dari tinggi ke rendah
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 3.459069262353263
# 2.7332266182220306
# 1.8432671623137584
# 1.3262301659142213
# 0.9476296834527308
# 0.88118663320406
# 0.8030043154958127
# 0.749504801856658
# 0.680143916709423
# 0.6354268725011191
# 0.582732279924806
# 0.5674237961513556
# 0.3905790289011323
# 0.3591770503049582
# 0.25897945228038927
# 0.24198192225199622
# 0.15741672229176149
# 0.05661133647851499

# %%
# Menghitung jumlah variasi data berdasarkan jumlah komponennya

tot = sum(eig_vals) # tot berjumlah 100
var_exp = [(i / tot)*100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
cum_var_exp
# Out:
# array([ 20.7457965 ,  37.13834574,  48.19335579,  56.14743217,
#         61.83084903,  67.11577315,  71.93179817,  76.42695942,
#         80.50612818,  84.3171061 ,  87.81204777,  91.21517668,
#         93.55767763,  95.71184496,  97.26507637,  98.71636495,
#         99.66047304, 100.        ])

# %% [markdown]
# ##### Menentukan komponen baru

# %%
# Perhitungan matematika

eigvectors_sorted= [eig_pairs[index][1] for index in range(len(eig_vals))]

D_reduce_s4 = np.array(eigvectors_sorted[0:11])   # Mengurangi dari 18 menjadi 11 dimensi

data_D_s4 = np.dot(X_train_smote_s4,D_reduce_s4.T)   # memproyeksikan data asli ke dalam dimensi komponen utama

data_reduced_pca_s4 = pd.DataFrame(data_D_s4)  # convert ke dataframe baru

data_reduced_pca_s4
# Out:
#            0         1         2   ...        8         9         10
# 0   -1.410408  2.053645  0.383173  ... -1.184869 -0.239870 -1.701708
# 1    1.446924 -1.875505  0.368764  ...  0.080060 -1.056497 -0.858873
# 2    2.799612  1.027663  0.539569  ... -0.232774  0.648641  0.578549
# 3    2.123281 -0.917044  1.690514  ...  0.007397  0.056329 -0.414090
# 4   -2.045603 -0.344590  0.219690  ...  0.297840 -0.456071  0.994665
# ..        ...       ...       ...  ...       ...       ...       ...
# 377  0.942759  1.193467 -0.420899  ... -0.065667 -0.359462 -0.317491
# 378 -2.019076 -0.576188 -0.551564  ... -0.023952 -0.245200 -0.087295
# 379  0.952372  1.027177 -0.458672  ... -0.257845 -0.149855 -0.058445
# 380  1.979691 -1.082529  1.963592  ...  0.404621 -1.166226  0.634168
# 381 -0.791531 -1.781495 -1.983637  ... -0.480199  0.119105  0.939691
#
# [382 rows x 11 columns]

# %% [markdown]
# ##### Predict

# %%
predict_s4 = np.dot(X_test_s4,D_reduce_s4.T)   # memproyeksikan data asli ke dalam dimensi 10 komponen utama
reduced_new = pd.DataFrame(predict_s4)  # convert ke dataframe baru
reduced_new
# Out:
#            0         1         2   ...        8         9         10
# 0   -0.787964 -1.858532 -0.427725  ...  0.200882 -1.641105  0.711340
# 1    0.804460 -1.022954  1.397935  ... -0.164794 -0.074016  0.047211
# 2   -1.114018 -1.463846 -1.049802  ... -0.292307 -0.208948 -0.260790
# 3    2.435865 -1.053907  2.094818  ...  0.533527 -0.601166  0.273372
# 4    0.622381 -2.212294 -2.533122  ... -0.287049 -0.056604  0.002659
# ..        ...       ...       ...  ...       ...       ...       ...
# 117  1.141286 -0.768172  1.687634  ... -1.679588 -0.486279 -0.228873
# 118 -1.786365  1.340924  3.899658  ... -1.559436 -1.044761  0.498163
# 119  1.492107  1.523961 -1.207022  ...  0.294746 -0.893015  0.641150
# 120 -0.311074 -1.121306 -0.547797  ...  2.237047 -0.670266  0.152352
# 121  4.577835  1.680672 -0.741034  ... -0.575659  0.210316 -0.022966
#
# [122 rows x 11 columns]

# %%
model_s4 = GaussianNB()
model_s4.fit(data_reduced_pca_s4, y_train_smote_s4)  
prediction_s4 = model_s4.predict(reduced_new)
  
# print classification report
print('Confusion Matrix \n', confusion_matrix(y_test_s4, prediction_s4))
print('\n Accuracy \n', accuracy_score(y_test_s4, prediction_s4))
print('\n Classification Report \n', classification_report(y_test_s4, prediction_s4))
print('AUC : ', roc_auc_score(y_test_s4, prediction_s4))
# Out:
# Confusion Matrix
#  [[57 25]
#  [ 9 31]]
#
#  Accuracy
#  0.7213114754098361
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.86      0.70      0.77        82
#            1       0.55      0.78      0.65        40
#
#     accuracy                           0.72       122
#    macro avg       0.71      0.74      0.71       122
# weighted avg       0.76      0.72      0.73       122
#
# AUC :  0.735060975609756

# %% [markdown]
# ### Save and Load Model

# %%
import pickle

model_filename = 'pca_model.pkl'
pickle.dump(model_s3, open(model_filename, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(model_filename, 'rb'))

# %% [markdown]
# ### Predict New Data

# %%
new_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SKRIPSI/Data Validasi.csv')

# %%
new_df
# Out:
#              Jurusan Jenis Kelamin  Usia  ... SKS 4 SKS 5  SKS 6
# 0   Sistem Informasi     Laki-laki    22  ...    23    23     23
# 1   Sistem Informasi     Perempuan    20  ...    23    23     23
# 2   Sistem Informasi     Perempuan    21  ...    23    23     23
# 3   Sistem Informasi     Perempuan    20  ...    23    23     23
# 4   Sistem Informasi     Perempuan    21  ...    23    23     23
# 5   Sistem Informasi     Perempuan    21  ...    23    23     23
# 6   Sistem Informasi     Perempuan    22  ...    23    23     23
# 7        Informatika     Laki-laki    22  ...    23    24     23
# 8        Informatika     Perempuan    20  ...    23    24     23
# 9        Informatika     Laki-laki    21  ...    23    24     23
# 10       Informatika     Perempuan    20  ...    23    24     23
# 11       Informatika     Laki-laki    21  ...    23    24     23
# 12       Informatika     Laki-laki    21  ...    20    24     23
# 13       Informatika     Laki-laki    21  ...    23    24     23
# 14       Informatika     Laki-laki    21  ...    23    21     23
#
# [15 rows x 18 columns]

# %%
new_df.shape
# Out:
# (15, 18)

# %%
# digunakan hanya di notebook

encoder= ce.OrdinalEncoder(mapping=[{'col':'Jurusan', 'mapping':{'Informatika':0, 'Sistem Informasi':1}},
                                    {'col':'Jenis Kelamin', 'mapping':{'Laki-laki':0, 'Perempuan':1}},
                                    {'col':'Asal', 'mapping':{'Surabaya':0, 'Luar Surabaya':1}},
                                    {'col':'Jalur Masuk', 'mapping':{'SNMPTN':0,'SBMPTN':1,'Mandiri':2}},
                                    {'col':'Organisasi', 'mapping':{'Ya':0, 'Tidak':1}}
                                    ])

new_df = encoder.fit_transform(new_df)

# %%
pickle.dump(encoder, open('encoder.pkl', 'wb'))

# %%
new_df
# Out:
#     Jurusan  Jenis Kelamin  Usia  Asal  ...  SKS 3  SKS 4  SKS 5  SKS 6
# 0         1              0    22     1  ...     23     23     23     23
# 1         1              1    20     1  ...     23     23     23     23
# 2         1              1    21     0  ...     23     23     23     23
# 3         1              1    20     1  ...     23     23     23     23
# 4         1              1    21     1  ...     23     23     23     23
# 5         1              1    21     1  ...     23     23     23     23
# 6         1              1    22     0  ...     23     23     23     23
# 7         0              0    22     1  ...     23     23     24     23
# 8         0              1    20     1  ...     23     23     24     23
# 9         0              0    21     1  ...     23     23     24     23
# 10        0              1    20     1  ...     23     23     24     23
# 11        0              0    21     0  ...     23     23     24     23
# 12        0              0    21     1  ...     23     20     24     23
# 13        0              0    21     0  ...     23     23     24     23
# 14        0              0    21     0  ...     23     23     21     23
#
# [15 rows x 18 columns]

# %%
# gunakan load pickle

# pertama
# scaler.pkl
normalize = pickle.load(open('scaler.pkl', 'rb'))
new_df = normalize.transform(new_df)
new_df

# %%
# kedua
# reduce.pkl
reduce_D = pickle.load(open('reduce.pkl', 'rb'))

new_df = np.dot(new_df,reduce_D.T)

# %%
# ketiga
# pca_model.pkl
model = pickle.load(open('pca_model.pkl', 'rb'))
model.predict(new_df)
